# %%
import pandas as pd
import random
import numpy as np

# %%
au = pd.read_csv("../au.csv")
au
# Out:
#                 city        lat         lng    country iso2  \
# 0             Sydney -33.861481  151.205475  Australia   AU
# 1    South Melbourne -37.833333  144.966667  Australia   AU
# 2           Brisbane -27.471010  153.024292  Australia   AU
# 3              Perth -31.952240  115.861397  Australia   AU
# 4           Adelaide -34.928661  138.598633  Australia   AU
# ..               ...        ...         ...        ...  ...
# 214         Windorah -25.422240  142.656597  Australia   AU
# 215         Bedourie -24.363700  139.465277  Australia   AU
# 216        Kingoonya -30.900000  135.300000  Australia   AU
# 217        Melbourne -37.813938  144.963425  Australia   AU
# 218           Currie -39.929759  143.853847  Australia   AU
#
#                  admin capital  population  population_proper
# 0      New South Wales   admin   4630000.0          3641422.0
# 1             Victoria     NaN   4170000.0            93625.0
# ...

# %%
au_towns = pd.read_csv("../au-towns-sample.csv")
au_towns
# Out:
#       id         name          urban_area state_code              state  \
# 0      1  Aarons Pass                 NaN        NSW    New South Wales
# 1      2   Abba River                 NaN         WA  Western Australia
# 2      3        Abbey           Busselton         WA  Western Australia
# 3      4     Abbeyard                 NaN        VIC           Victoria
# 4      5    Abbeywood                 NaN        QLD         Queensland
# ..   ...          ...                 ...        ...                ...
# 459  460    Axe Creek                 NaN        VIC           Victoria
# 460  461      Axedale                 NaN        VIC           Victoria
# 461  462    Aylmerton  Bowral - Mittagong        NSW    New South Wales
# 462  463          Ayr                 NaN        QLD         Queensland
# 463  464      Ayrford                 NaN        VIC           Victoria
#
#      postcode            type  latitude  longitude  elevation  population  \
# ...

# %%
au_towns[au_towns["state_code"] == "ACT"]
# Out:
#       id               name          urban_area state_code            state  \
# 0      1        Aarons Pass                 NaN        NSW  New South Wales
# 5      6         Abbotsbury              Sydney        NSW  New South Wales
# 6      7         Abbotsford              Sydney        NSW  New South Wales
# 12    13        Abercrombie            Bathurst        NSW  New South Wales
# 13    14  Abercrombie River                 NaN        NSW  New South Wales
# ..   ...                ...                 ...        ...              ...
# 448  449               Avon                 NaN        NSW  New South Wales
# 450  451           Avondale                 NaN        NSW  New South Wales
# 455  456           Avonside                 NaN        NSW  New South Wales
# 458  459              Awaba                 NaN        NSW  New South Wales
# 461  462          Aylmerton  Bowral - Mittagong        NSW  New South Wales
#
# ...

# %%
au_towns[au_towns["urban_area"] == "Canberra"]
# Out:
#       id     name urban_area state_code                         state  \
# 35    36    Acton   Canberra        ACT  Australian Capital Territory
# 63    64  Ainslie   Canberra        ACT  Australian Capital Territory
# 185  186   Amaroo   Canberra        ACT  Australian Capital Territory
# 289  290   Aranda   Canberra        ACT  Australian Capital Territory
#
#      postcode    type  latitude  longitude  elevation  population  \
# 35       2601  Suburb -35.28732  149.11213        556        2086
# 63       2602  Suburb -35.26215  149.14589        593        5189
# 185      2914  Suburb -35.17033  149.12588        631        5710
# 289      2614  Suburb -35.25796  149.07565        632        2393
#
#      median_income  area_sq_km local_government_area  \
# 35            9308       5.989        Unincorporated
# 63           53508       3.541        Unincorporated
# 185          56680       2.587        Unincorporated
# 289          62140       1.563        Unincorporated
#
# ...

# %%
au_towns[au_towns["state_code"] == "NSW"]
# Out:
#       id               name          urban_area state_code            state  \
# 0      1        Aarons Pass                 NaN        NSW  New South Wales
# 5      6         Abbotsbury              Sydney        NSW  New South Wales
# 6      7         Abbotsford              Sydney        NSW  New South Wales
# 12    13        Abercrombie            Bathurst        NSW  New South Wales
# 13    14  Abercrombie River                 NaN        NSW  New South Wales
# ..   ...                ...                 ...        ...              ...
# 448  449               Avon                 NaN        NSW  New South Wales
# 450  451           Avondale                 NaN        NSW  New South Wales
# 455  456           Avonside                 NaN        NSW  New South Wales
# 458  459              Awaba                 NaN        NSW  New South Wales
# 461  462          Aylmerton  Bowral - Mittagong        NSW  New South Wales
#
# ...

# %%
for i, e in enumerate(au_towns["state_code"].unique()):
    print(i, e)
    print(au_towns[au_towns["state_code"] == e]["name","state_code"])
# Out:
# 0 NSW
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'state_code')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c10749364b00> in <module>
# ...
